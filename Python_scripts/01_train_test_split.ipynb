# %% [markdown]
# # Patient-level Stratified Train/Test Split (Polars + scikit-learn)
#
# This notebook:
# - Loads **three CSVs** (`ml_oneicu.csv`, `ml_eicu.csv`, `ml_mimiciv.csv`) from `../data`
# - Performs a **patient-level** (i.e., `icu_stay_id`-level) **train/test split** with **stratification by `outcome_lead`**
# - Uses an **80/20** split (configurable)
# - Writes **two CSVs per dataset** into `../data/machine_learning`: `<db>_train.csv` and `<db>_test.csv`
#
# **Key points**
# - We split by `icu_stay_id` to avoid leaking a patient's time-series across train and test.
# - Stratification is based on a **stay-level** label computed from `outcome_lead` using `max` (any positive row ⇒ positive stay). You can switch to mean/threshold if you prefer.
# - If stratification is infeasible (e.g., a class has fewer than 2 stays), we fall back to a grouped random split and log a warning.

# %%
from pathlib import Path
import logging
import warnings
import gc

import polars as pl
from sklearn.model_selection import train_test_split

# ---- parameters (edit here if needed) ----
data_dir = Path("../data/machine_learning")
out_dir = Path("../data/machine_learning")

id_col = "icu_stay_id"
label_col = "outcome_lead"

test_size = 0.2
random_state = 813

logging.basicConfig(level=20, format="%(asctime)s %(levelname)s %(message)s")

# %%
def read_ml_csvs(data_dir: Path) -> dict[str, pl.DataFrame]:
    dfs: dict[str, pl.DataFrame] = {}

    # --- CHANGED: handle ml_oneicu split across two files ---
    oneicu_1_path = data_dir / "ml_oneicu_1.csv"
    oneicu_2_path = data_dir / "ml_oneicu_2.csv"

    if oneicu_1_path.exists() and oneicu_2_path.exists():
        logging.info("Reading split ml_oneicu: %s + %s", oneicu_1_path.name, oneicu_2_path.name)

        df_oneicu_1 = pl.read_csv(oneicu_1_path, infer_schema_length=None, low_memory=True)
        df_oneicu_2 = pl.read_csv(oneicu_2_path, infer_schema_length=None, low_memory=True)

        # Concatenate the two parts into the single dataset you expect downstream
        dfs["ml_oneicu"] = pl.concat(
            [df_oneicu_1, df_oneicu_2],
            how="vertical",
            rechunk=False,  # keep this False to avoid an extra full copy in memory
        )

        # --- CHANGED: delete intermediates to drop references ASAP ---
        del df_oneicu_1, df_oneicu_2
        gc.collect()

    else:
        raise FileNotFoundError(
            f"Expected either {oneicu_path.name} OR both {oneicu_1_path.name} and {oneicu_2_path.name} in {data_dir}"
        )

    # --- CHANGED: read the rest of the CSVs, skipping the oneicu file(s) so they aren't loaded twice ---
    skip = {"ml_oneicu_1.csv", "ml_oneicu_2.csv"}
    for p in data_dir.glob("*.csv"):
        if p.name in skip:
            continue
        dfs[p.stem] = pl.read_csv(p, infer_schema_length=None, low_memory=True)

    return dfs


def stay_level_labels(df, id_col=id_col, label_col=label_col):
    """
    compute stay-level labels from row-level outcome by max aggregation.
    returns a dataframe with columns: [id_col, "y"] where y in {0,1}.
    """
    return (
        df
        .group_by(id_col)
        .agg(pl.col(label_col).max().alias("y"))
        .select(id_col, "y")
    )


def stratified_split_by_patient(
    df,
    id_col=id_col,
    label_col=label_col,
    test_size=test_size,
    random_state=random_state,
):
    """
    split by icu_stay_id with stratification on stay-level labels (max of outcome).
    falls back to grouped split without stratify if a class has < 2 stays.
    """
    stay_y = stay_level_labels(df, id_col=id_col, label_col=label_col)
    ids = stay_y[id_col].to_list()
    y = stay_y["y"].to_list()

    # class counts
    counts = {}
    for v in y:
        counts[v] = counts.get(v, 0) + 1

    stratify = y if len(counts) >= 2 and min(counts.values()) >= 2 else None
    if stratify is None:
        warnings.warn(f"cannot stratify: class counts {counts}. proceeding without stratification.")

    train_ids, test_ids = train_test_split(
        ids,
        test_size=test_size,
        random_state=random_state,
        shuffle=True,
        stratify=stratify,
    )

    train_df = df.filter(pl.col(id_col).is_in(train_ids))
    test_df = df.filter(pl.col(id_col).is_in(test_ids))

    # sanity check: no leakage of stays
    train_stays = set(train_df.select(id_col).unique().to_series().to_list())
    test_stays = set(test_df.select(id_col).unique().to_series().to_list())
    assert train_stays.isdisjoint(test_stays), "leakage detected: some icu_stay_id appear in both train and test."

    logging.info(
        "split by %s: stays train/test = %d/%d, rows train/test = %d/%d",
        id_col,
        stay_y.filter(pl.col(id_col).is_in(train_ids)).height,
        stay_y.filter(pl.col(id_col).is_in(test_ids)).height,
        train_df.height,
        test_df.height,
    )
    return train_df, test_df


def stays_and_rows(df: pl.DataFrame, id_col=id_col) -> tuple[int, int]:
    stats = df.select(
        pl.col(id_col).n_unique().alias("stays"),
        pl.len().alias("rows"),
    ).to_dicts()[0]
    return int(stats["stays"]), int(stats["rows"])


def save_train_test_csvs(
    dfs,
    out_dir,
    id_col=id_col,
    label_col=label_col,
    test_size=test_size,
    random_state=random_state,
):
    """for each dataset, perform the patient-level split and write train/test csvs."""
    out_dir.mkdir(parents=True, exist_ok=True)

    for name, df in dfs.items():
        logging.info("processing dataset: %s", name)

        pre_stays, pre_rows = stays_and_rows(df, id_col=id_col)
        print(f"[{name}] pre-split: unique {id_col} = {pre_stays:,}, rows (person-hours) = {pre_rows:,}")

        train_df, test_df = stratified_split_by_patient(
            df,
            id_col=id_col,
            label_col=label_col,
            test_size=test_size,
            random_state=random_state,
        )

        tr_stays, tr_rows = stays_and_rows(train_df, id_col=id_col)
        te_stays, te_rows = stays_and_rows(test_df, id_col=id_col)
        print(
            f"[{name}] post-split: "
            f"train unique {id_col} = {tr_stays:,}, train rows = {tr_rows:,} | "
            f"test unique {id_col} = {te_stays:,}, test rows = {te_rows:,}"
        )

        train_path = out_dir / f"{name}_train.csv"
        test_path = out_dir / f"{name}_test.csv"

        train_df.write_csv(train_path)
        test_df.write_csv(test_path)

        logging.info("wrote: %s (%d rows)", train_path, train_df.height)
        logging.info("wrote: %s (%d rows)", test_path, test_df.height)

# %%
dfs = read_ml_csvs(data_dir)
# quick row counts per dataset
{key: df.height for key, df in dfs.items()}
# Out:
# 2026-01-03 22:49:47,379 INFO Reading split ml_oneicu: ml_oneicu_1.csv + ml_oneicu_2.csv
# {'ml_oneicu': 2780556, 'ml_mimiciv': 3985871, 'ml_eicu': 1140102}

# %%
def stay_class_counts(df):
    counts_df = stay_level_labels(df, id_col, label_col).group_by("y").count()
    return {int(row["y"]): int(row["count"]) for row in counts_df.iter_rows(named=True)}

# %%
save_train_test_csvs(
    dfs=dfs,
    out_dir=out_dir,
    id_col=id_col,
    label_col=label_col,
    test_size=test_size,
    random_state=random_state,
)

print("done. files written to:", out_dir.resolve())
# Out:
# 2026-01-03 22:50:02,969 INFO processing dataset: ml_oneicu
# [ml_oneicu] pre-split: unique icu_stay_id = 75,337, rows (person-hours) = 2,780,556
# 2026-01-03 22:50:04,187 INFO split by icu_stay_id: stays train/test = 60269/15068, rows train/test = 2240897/539659
# [ml_oneicu] post-split: train unique icu_stay_id = 60,269, train rows = 2,240,897 | test unique icu_stay_id = 15,068, test rows = 539,659
# 2026-01-03 22:50:06,902 INFO wrote: ../data/machine_learning/ml_oneicu_train.csv (2240897 rows)
# 2026-01-03 22:50:06,908 INFO wrote: ../data/machine_learning/ml_oneicu_test.csv (539659 rows)
# 2026-01-03 22:50:06,908 INFO processing dataset: ml_mimiciv
# [ml_mimiciv] pre-split: unique icu_stay_id = 75,668, rows (person-hours) = 3,985,871
# 2026-01-03 22:50:07,353 INFO split by icu_stay_id: stays train/test = 60534/15134, rows train/test = 3186092/799779
# [ml_mimiciv] post-split: train unique icu_stay_id = 60,534, train rows = 3,186,092 | test unique icu_stay_id = 15,134, test rows = 799,779
# 2026-01-03 22:50:08,638 INFO wrote: ../data/machine_learning/ml_mimiciv_train.csv (3186092 rows)
# 2026-01-03 22:50:08,639 INFO wrote: ../data/machine_learning/ml_mimiciv_test.csv (799779 rows)
# 2026-01-03 22:50:08,639 INFO processing dataset: ml_eicu
# [ml_eicu] pre-split: unique icu_stay_id = 32,471, rows (person-hours) = 1,140,102
# 2026-01-03 22:50:08,872 INFO split by icu_stay_id: stays train/test = 25976/6495, rows train/test = 910474/229628
# [ml_eicu] post-split: train unique icu_stay_id = 25,976, train rows = 910,474 | test unique icu_stay_id = 6,495, test rows = 229,628
# 2026-01-03 22:50:09,685 INFO wrote: ../data/machine_learning/ml_eicu_train.csv (910474 rows)
# 2026-01-03 22:50:09,686 INFO wrote: ../data/machine_learning/ml_eicu_test.csv (229628 rows)
# done. files written to: /Users/kinoshitatakashihiroshi/Dropbox/VS_Code/OneICU_profile_paper/data/machine_learning
