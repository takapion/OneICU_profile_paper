# %% [markdown]
# # ROC evaluation for H2O AutoML leaders and GLMs (OneICU / MIMIC‑IV / eICU)
#
# This notebook:
# - loads `leader` (best) and `glm` models saved by the H2O AutoML training pipeline for each dataset
# - imports the corresponding **test** split from `../data/machine_learning`
# - computes **AUROC** for both models (GLM and leader) on each dataset
# - draws two ROC figures with **seaborn** (white background, **no grid lines**):
#   1) GLM models compared across datasets
#   2) Best (leader) models compared across datasets
# - saves figures as half‑column width **TIFF** files at **600 dpi** under `../output/machine_learning`
#
# Datasets and display settings:
# - Datasets: `oneicu`, `mimiciv`, `eicu`
# - Display labels: **OneICU**, **MIMIC‑IV**, **eICU**
# - Colors: `oneicu=#6CC5B0FF`, `mimiciv=#4269D0FF`, `eicu=#FF8AB7FF`
#
# Requirements: `h2o`, `seaborn`, `matplotlib`, `pandas`, `scikit-learn`

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, auc
import h2o

import logging

data_dir = Path("../data/machine_learning")
models_root = Path("../output/models")
out_dir = Path("../output/machine_learning")
out_dir.mkdir(parents=True, exist_ok=True)


target = "outcome_lead"
target_sens = 0.90
target_spec = 0.90


metrics_sens_csv = out_dir / "metrics_threshold_sensitivity_90_best_models.csv"
metrics_spec_csv = out_dir / "metrics_threshold_specificity_90_best_models.csv"


model_specs = [
    # 1) OneICU every minute MBP model (all features; includes invasive_mbp_00..59)
    {
        "dataset": "oneicu",
        "model_tag": "all_features",
        "label": "OneICU 1-minute MAP model",
        "color": "#6CC5B0",
    },
    # 2) OneICU every 5-minute MBP model
    {
        "dataset": "oneicu",
        "model_tag": "mbp_5min_only",
        "label": "OneICU 5-minute MAP model",
        "color": "#9CD7C7",
    },
    # 3) OneICU hourly MBP model (mbp_00 only among invasive_mbp_XX)
    {
        "dataset": "oneicu",
        "model_tag": "mbp_00_only",
        "label": "OneICU hourly MAP model",
        "color": "#C7E8DF",
    },
    # 4) eICU (every 5-minute MBP model)
    {
        "dataset": "eicu",
        "model_tag": "all_features",
        "label": "eICU (5-minute MAP model)",
        "color": "#FF8AB7",
    },
    # 5) MIMIC-IV (hourly MBP model)
    {
        "dataset": "mimiciv",
        "model_tag": "all_features",
        "label": "MIMIC-IV (hourly MAP model)",
        "color": "#4269D0",
    },
]


fig_width_in = 3.35
fig_height_in = 3.35
fig_dpi = 900

sns.set_theme(
    style="white",
    context="notebook",
    rc={
        "font.size": 7,        # base font size
        "axes.titlesize": 7,   # axes title
        "axes.labelsize": 7,   # x/y labels
        "legend.fontsize": 6,  # legend
        "xtick.labelsize": 6,  # ticks
        "ytick.labelsize": 6,
    },
)
plt.rcParams["axes.grid"] = False

h2o.init()
h2o.no_progress()

logging.basicConfig(level=20, format="%(asctime)s %(levelname)s %(message)s")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "21.0.3" 2024-04-16; OpenJDK Runtime Environment Homebrew (build 21.0.3); OpenJDK 64-Bit Server VM Homebrew (build 21.0.3, mixed mode, sharing)
#   Starting server from /Users/kinoshitatakashihiroshi/Dropbox/VS_Code/OneICU_profile_paper/.venv/lib/python3.12/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/c8/r1g7pwls4d504kywff1wyfl80000gn/T/tmp5kp4ki84
#   JVM stdout: /var/folders/c8/r1g7pwls4d504kywff1wyfl80000gn/T/tmp5kp4ki84/h2o_kinoshitatakashihiroshi_started_from_python.out
#   JVM stderr: /var/folders/c8/r1g7pwls4d504kywff1wyfl80000gn/T/tmp5kp4ki84/h2o_kinoshitatakashihiroshi_started_from_python.err
#   Server is running at http://127.0.0.1:54323
# Connecting to H2O server at http://127.0.0.1:54323 ... successful.
# ...

# %%
def load_manifest(dataset: str, model_tag: str) -> dict:
    """
    Prefer: models_root/dataset/model_tag/manifest.json
    Fallback (legacy): models_root/dataset/manifest.json (only when model_tag == 'all_features')
    """
    tagged = models_root / dataset / model_tag / "manifest.json"
    legacy = models_root / dataset / "manifest.json"

    if tagged.exists():
        mpath = tagged
    elif model_tag == "all_features" and legacy.exists():
        mpath = legacy
    else:
        raise FileNotFoundError(
            f"Missing manifest for dataset={dataset}, tag={model_tag}. "
            f"Looked for {tagged} (and legacy {legacy})."
        )

    with open(mpath, "r", encoding="utf-8") as f:
        return json.load(f)


def load_models_and_features(dataset: str, model_tag: str):
    """
    kind: "leader" or "glm"
    returns (h2o_model, feature_list)
    """
    man = load_manifest(dataset, model_tag)
    leader = h2o.load_model(man["leader_model_path"])
    glm_model = h2o.load_model(man["glm_model_path"])
    feats = man.get("features", [])
    if not feats:
        raise ValueError(f"No features found in manifest for dataset={dataset}, tag={model_tag}")
    return leader, glm_model, feats


def get_test_raw(dataset: str):
    test_path = data_dir / f"ml_{dataset}_test.csv"
    if not test_path.exists():
        raise FileNotFoundError(f"Missing test CSV for {dataset}: {test_path}")
    return h2o.import_file(test_path.as_posix())


def prepare_test_view(test_raw, feats: list[str]):
    # validate all needed columns exist
    missing = [c for c in feats if c not in test_raw.columns]
    if missing:
        raise ValueError(f"Test frame missing training features: {missing[:8]}{'...' if len(missing) > 8 else ''}")

    # slice to feats + target
    test_use = test_raw[:, feats + [target]]

    # enforce types
    for c in feats:
        test_use[c] = test_use[c].asnumeric()
    test_use[target] = test_use[target].asfactor()
    return test_use


def y_true_from_test(test) -> np.ndarray:
    """y_true as integers 0/1 (handles string factors '0'/'1')."""
    y_true = test[target].as_data_frame(use_pandas=True, use_multi_thread=True)[target]
    y_true = pd.to_numeric(y_true, errors="coerce").astype(int).values
    return y_true


def y_score_from_model(model, test) -> np.ndarray:
    """predicted prob for positive class (p1)."""
    pred = model.predict(test)
    y_score = pred["p1"].as_data_frame(use_pandas=True, use_multi_thread=True).values.ravel().astype(float)
    # remove prediction frame to keep cluster memory stable
    h2o.remove(pred)
    return y_score


def roc_from_model(model, test, y_true=None, y_score=None):
    """
    compute ROC arrays and AUROC for a given H2O model and H2OFrame test.
    """
    if y_true is None:
        y_true = y_true_from_test(test)
    if y_score is None:
        y_score = y_score_from_model(model, test)

    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)
    return fpr, tpr, roc_auc


def plot_roc_curves(curves, title: str, out_path: Path):
    """plot ROC curves with seaborn (white background, no grid), save as TIFF."""
    fig, ax = plt.subplots(figsize=(fig_width_in, fig_height_in))

    for c in curves:
        sns.lineplot(
            x=c["fpr"], y=c["tpr"], ax=ax,
            label=f"{c['label']} (AUROC={c['auc']:.3f})",
            color=c["color"], linewidth=0.6
        )

    # diagonal baseline
    ax.plot([0, 1], [0, 1], linestyle="--", linewidth=0.6, color="#888888")

    # cosmetics: white background, no grid, clean spines
    ax.set_xlim(0.0, 1.0)
    ax.set_ylim(0.0, 1.0)
    ax.spines['bottom'].set_linewidth(0.6)
    ax.spines['left'].set_linewidth(0.6)
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title(title)
    ax.grid(False)
    sns.despine(ax=ax)
    ax.legend(loc="lower right", frameon=False)

    fig.tight_layout()
    fig.savefig(out_path, dpi=fig_dpi, format="tiff")
    plt.close(fig)


def pick_threshold_for_sensitivity(y_true: np.ndarray, y_score: np.ndarray, target_sens: float) -> float:
    """
    Choose a threshold that achieves sensitivity >= target_sens, maximizing specificity among those.
    If target can't be reached, choose the threshold with max sensitivity.
    """
    fpr, tpr, thr = roc_curve(y_true, y_score, drop_intermediate=False)
    spec = 1.0 - fpr

    finite = np.isfinite(thr)
    tpr, spec, thr = tpr[finite], spec[finite], thr[finite]

    ok = np.where(tpr >= target_sens)[0]
    if ok.size == 0:
        idx = int(np.argmax(tpr))
    else:
        idx = int(ok[np.argmax(spec[ok])])
    return float(thr[idx])


def pick_threshold_for_specificity(y_true: np.ndarray, y_score: np.ndarray, target_spec: float) -> float:
    """
    Choose a threshold that achieves specificity >= target_spec, maximizing sensitivity among those.
    If target can't be reached, choose the threshold with max specificity.
    """
    fpr, tpr, thr = roc_curve(y_true, y_score, drop_intermediate=False)
    spec = 1.0 - fpr

    finite = np.isfinite(thr)
    tpr, spec, thr = tpr[finite], spec[finite], thr[finite]

    ok = np.where(spec >= target_spec)[0]
    if ok.size == 0:
        idx = int(np.argmax(spec))
    else:
        idx = int(ok[np.argmax(tpr[ok])])
    return float(thr[idx])


def metrics_at_threshold(y_true: np.ndarray, y_score: np.ndarray, thr: float):
    """Return (sens, spec, ppv, npv, tp, fp, tn, fn) at threshold thr."""
    y_pred = (y_score >= thr).astype(int)

    tp = int(np.sum((y_true == 1) & (y_pred == 1)))
    fp = int(np.sum((y_true == 0) & (y_pred == 1)))
    tn = int(np.sum((y_true == 0) & (y_pred == 0)))
    fn = int(np.sum((y_true == 1) & (y_pred == 0)))

    sens = tp / (tp + fn) if (tp + fn) else np.nan
    spec = tn / (tn + fp) if (tn + fp) else np.nan
    ppv  = tp / (tp + fp) if (tp + fp) else np.nan
    npv  = tn / (tn + fn) if (tn + fn) else np.nan

    return sens, spec, ppv, npv, tp, fp, tn, fn

# %%
curves_glm = []
curves_leader = []
auc_rows = []

metric_rows_sens90 = []
metric_rows_spec90 = []

# cache test frames per dataset (avoid repeated CSV imports)
test_cache = {}

for spec in model_specs:
    ds = spec["dataset"]
    tag = spec["model_tag"]
    label = spec["label"]
    color = spec["color"]

    logging.info("=== %s | dataset=%s tag=%s ===", label, ds, tag)

    # load models + features
    leader, glm_model, feats = load_models_and_features(ds, tag)

    # import test once per dataset
    if ds not in test_cache:
        test_cache[ds] = get_test_raw(ds)
    test_raw = test_cache[ds]

    # prepare test view for this feature set
    test_use = prepare_test_view(test_raw, feats)

    # compute y_true once (shared by GLM + leader)
    y_true = y_true_from_test(test_use)

    # ---- GLM ROC ----
    y_score_glm = y_score_from_model(glm_model, test_use)
    fpr_g, tpr_g, auc_g = roc_from_model(glm_model, test_use, y_true=y_true, y_score=y_score_glm)
    curves_glm.append({"label": label, "color": color, "fpr": fpr_g, "tpr": tpr_g, "auc": auc_g})

    # ---- Leader ROC ----
    y_score_leader = y_score_from_model(leader, test_use)
    fpr_l, tpr_l, auc_l = roc_from_model(leader, test_use, y_true=y_true, y_score=y_score_leader)
    curves_leader.append({"label": label, "color": color, "fpr": fpr_l, "tpr": tpr_l, "auc": auc_l})

    auc_rows.append({
        "model": label,
        "dataset": ds,
        "model_tag": tag,
        "glm_auroc": round(float(auc_g), 4),
        "best_model_auroc": round(float(auc_l), 4),
        "n_test_rows": int(test_use.nrows),
    })

    # ---------------------------
    # metrics (Best model / leader) at sens=0.90 and spec=0.90
    # ---------------------------
    thr_s = pick_threshold_for_sensitivity(y_true, y_score_leader, target_sens)
    sens_s, spec_s, ppv_s, npv_s, tp_s, fp_s, tn_s, fn_s = metrics_at_threshold(y_true, y_score_leader, thr_s)

    metric_rows_sens90.append({
        "model": label,
        "threshold": thr_s,
        "sensitivity": sens_s,
        "specificity": spec_s,
        "ppv": ppv_s,
        "npv": npv_s,
        "tp": tp_s, "fp": fp_s, "tn": tn_s, "fn": fn_s,
        "n_test_rows": int(test_use.nrows),
    })

    thr_p = pick_threshold_for_specificity(y_true, y_score_leader, target_spec)
    sens_p, spec_p, ppv_p, npv_p, tp_p, fp_p, tn_p, fn_p = metrics_at_threshold(y_true, y_score_leader, thr_p)

    metric_rows_spec90.append({
        "model": label,
        "threshold": thr_p,
        "sensitivity": sens_p,
        "specificity": spec_p,
        "ppv": ppv_p,
        "npv": npv_p,
        "tp": tp_p, "fp": fp_p, "tn": tn_p, "fn": fn_p,
        "n_test_rows": int(test_use.nrows),
    })

    # cleanup per spec
    h2o.remove(test_use)
    # remove models from cluster to avoid buildup
    try:
        h2o.remove(leader)
    except Exception:
        pass
    try:
        h2o.remove(glm_model)
    except Exception:
        pass

    del leader, glm_model, feats, test_use, y_true, y_score_glm, y_score_leader

# remove cached raw tests
for fr in test_cache.values():
    h2o.remove(fr)
test_cache.clear()
# Out:
# 2026-01-04 23:41:25,891 INFO === OneICU 1-minute MAP model | dataset=oneicu tag=all_features ===
# /Users/kinoshitatakashihiroshi/Dropbox/VS_Code/OneICU_profile_paper/.venv/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /Users/kinoshitatakashihiroshi/Dropbox/VS_Code/OneICU_profile_paper/.venv/lib/python3.12/site-packages/h2o/frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
# ...

# %%
# print compact summary table
summary_auc_df = pd.DataFrame(auc_rows)
print("\n=== AUROC summary ===")
print(summary_auc_df.to_string(index=False))
# Out:
# === AUROC summary ===
#                       model dataset     model_tag  glm_auroc  best_model_auroc  n_test_rows
#   OneICU 1-minute MAP model  oneicu  all_features     0.9303            0.9415       539659
#   OneICU 5-minute MAP model  oneicu mbp_5min_only     0.9273            0.9391       539659
#     OneICU hourly MAP model  oneicu   mbp_00_only     0.8957            0.9009       539659
#   eICU (5-minute MAP model)    eicu  all_features     0.8850            0.8989       229628
# MIMIC-IV (hourly MAP model) mimiciv  all_features     0.8218            0.7993       799779

# %%
# plot and save figures
glm_tiff = out_dir / "roc_glm_three_datasets.tiff"
best_tiff = out_dir / "roc_best_three_datasets.tiff"
plot_roc_curves(curves_glm, "Logistic regression models", glm_tiff)
plot_roc_curves(curves_leader, "Best machine learning models", best_tiff)

print("\nSaved ROC figures:")
print(" -", glm_tiff)
print(" -", best_tiff)
# Out:
# Saved ROC figures:
#  - ../output/machine_learning/roc_glm_three_datasets.tiff
#  - ../output/machine_learning/roc_best_three_datasets.tiff

# %%
df_metrics_sens90 = pd.DataFrame(metric_rows_sens90)
df_metrics_spec90 = pd.DataFrame(metric_rows_spec90)

# (optional) rounding for readability
for df in (df_metrics_sens90, df_metrics_spec90):
    for c in ["threshold", "sensitivity", "specificity", "ppv", "npv"]:
        df[c] = df[c].astype(float)
    df["threshold"] = df["threshold"].round(6)
    df["sensitivity"] = df["sensitivity"].round(4)
    df["specificity"] = df["specificity"].round(4)
    df["ppv"] = df["ppv"].round(4)
    df["npv"] = df["npv"].round(4)

df_metrics_sens90.to_csv(metrics_sens_csv, index=False)
df_metrics_spec90.to_csv(metrics_spec_csv, index=False)

print("\nSaved metrics CSVs (Best models / leaders):")
print(" -", metrics_sens_csv)
print(" -", metrics_spec_csv)

print("\nMetrics @ threshold targeting sensitivity=0.90 (leader):")
print(df_metrics_sens90[["model", "threshold", "sensitivity", "specificity", "ppv", "npv"]].to_string(index=False))

print("\nMetrics @ threshold targeting specificity=0.90 (leader):")
print(df_metrics_spec90[["model", "threshold", "sensitivity", "specificity", "ppv", "npv"]].to_string(index=False))
# Out:
# Saved metrics CSVs (Best models / leaders):
#  - ../output/machine_learning/metrics_threshold_sensitivity_90_best_models.csv
#  - ../output/machine_learning/metrics_threshold_specificity_90_best_models.csv
#
# Metrics @ threshold targeting sensitivity=0.90 (leader):
#                       model  threshold  sensitivity  specificity    ppv    npv
#   OneICU 1-minute MAP model   0.083580          0.9       0.8326 0.4414 0.9827
#   OneICU 5-minute MAP model   0.081092          0.9       0.8244 0.4297 0.9825
#     OneICU hourly MAP model   0.055410          0.9       0.7026 0.3079 0.9795
#   eICU (5-minute MAP model)   0.059949          0.9       0.7082 0.2834 0.9822
# MIMIC-IV (hourly MAP model)   0.073102          0.9       0.3807 0.1650 0.9655
#
# Metrics @ threshold targeting specificity=0.90 (leader):
#                       model  threshold  sensitivity  specificity    ppv    npv
#   OneICU 1-minute MAP model   0.166253       0.8358          0.9 0.5513 0.9739
# ...
